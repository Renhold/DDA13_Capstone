# %%
import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle, islice

# %%
pic = pd.DataFrame({
   'percent': [28.4, 26.1, 12.9, 9.7, 9.4, 7.5, 5.9],
   'labels': ['Transport to ER','Provided Resources', 'Other', 'Transport Inpatient','Refused Resources','Collection of Collateral','Transport to CTC']
})

# %%
pic
# Out:
#    percent                    labels
# 0     28.4           Transport to ER
# 1     26.1        Provided Resources
# 2     12.9                     Other
# 3      9.7       Transport Inpatient
# 4      9.4         Refused Resources
# 5      7.5  Collection of Collateral
# 6      5.9          Transport to CTC

# %%
pic.plot(kind='bar', x='labels', y='percent', legend=False, color=(.2,.7,.2))
plt.xlabel("Event Outcomes") 
plt.ylabel("Percentage")
plt.title("CIT Event Outcomes - 2023")
plt.xticks(fontsize=8, rotation=20)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Transport to ER'),
#   Text(1, 0, 'Provided Resources'),
#   Text(2, 0, 'Other'),
#   Text(3, 0, 'Transport Inpatient'),
#   Text(4, 0, 'Refused Resources'),
#   Text(5, 0, 'Collection of Collateral'),
#   Text(6, 0, 'Transport to CTC')])
